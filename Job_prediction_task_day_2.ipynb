# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveen2005-08/AI-ML-task-DAY---1/blob/main/Job_prediction_task_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Create Dataset


data = {
    "Student_ID": range(1, 21),

    "CGPA": [
        8.5, 7.2, 6.1, 8.9, 7.8,
        5.9, 8.2, 6.8, 7.5, 9.0,
        6.3, 8.0, 7.1, 5.7, 8.7,
        6.5, 7.9, 5.5, 8.4, 7.0
    ],

    "Aptitude_Score": [
        85, 72, 55, 92, 78,
        48, 88, 62, 75, 95,
        58, 82, 70, 45, 90,
        60, 80, 42, 86, 68
    ],

    "Technical_Score": [
        88, 75, 52, 95, 82,
        45, 90, 65, 78, 96,
        55, 85, 72, 40, 92,
        62, 84, 38, 89, 70
    ],

    "Communication_Score": [
        80, 72, 60, 90, 75,
        55, 85, 65, 78, 92,
        58, 82, 70, 48, 88,
        62, 80, 50, 86, 68
    ],

    "Internship": [
        "Yes", "Yes", "No", "Yes", "Yes",
        "No", "Yes", "No", "Yes", "Yes",
        "No", "Yes", "Yes", "No", "Yes",
        "No", "Yes", "No", "Yes", "Yes"
    ],

    "Projects": [
        3, 2, 1, 4, 3,
        0, 4, 1, 2, 5,
        1, 3, 2, 0, 4,
        1, 3, 0, 4, 2
    ],

    "Certifications": [
        2, 1, 0, 3, 2,
        0, 3, 1, 2, 4,
        0, 2, 1, 0, 3,
        1, 2, 0, 3, 1
    ],

    "Backlogs": [
        0, 0, 2, 0, 0,
        3, 0, 1, 0, 0,
        2, 0, 0, 4, 0,
        1, 0, 3, 0, 0
    ],

    "Placement": [
        "Placed", "Placed", "Not Placed", "Placed", "Placed",
        "Not Placed", "Placed", "Not Placed", "Placed", "Placed",
        "Not Placed", "Placed", "Placed", "Not Placed", "Placed",
        "Not Placed", "Placed", "Not Placed", "Placed", "Placed"
    ]
}



#Create DataFrame


df = pd.DataFrame(data)

print(df)



#Display First 5 Rows


print("First 5 rows:")
print(df.head())



# Display Last 5 Rows


print("Last 5 rows:")
print(df.tail())



#Understand Dataset Shape


print("Dataset Shape:")
print(df.shape)



#Understand Columns


print("Column Names:")
print(df.columns)



#Dataset Information


print("Dataset Information:")
df.info()


#Statistical Summary


print("Statistical Summary:")
print(df.describe())


#Check Data Types


print("Data Types:")
print(df.dtypes)


#Check Missing Values


print("Missing Values:")
print(df.isnull().sum())


# Check Duplicate Rows


print("Number of Duplicate Rows:")
print(df.duplicated().sum())


# Select a Column


print("CGPA Column:")
print(df["CGPA"])


# Select Multiple Columns


print("Selected Columns:")
print(df[["CGPA", "Aptitude_Score", "Technical_Score", "Placement"]])


# Basic Filtering


print("Students with CGPA greater than 8:")
print(df[df["CGPA"] > 8])


#Students Who Got Placed


print("Placed Students:")
print(df[df["Placement"] == "Placed"])


#Students Who Did Not Get Placed


print("Not Placed Students:")
print(df[df["Placement"] == "Not Placed"])


# Cell 18: Average CGPA


average_cgpa = df["CGPA"].mean()

print("Average CGPA:", average_cgpa)


#  Average Aptitude Score


average_aptitude = df["Aptitude_Score"].mean()

print("Average Aptitude Score:", average_aptitude)



#Placement Count


print("Placement Count:")
print(df["Placement"].value_counts())



# Internship Count


print("Internship Count:")
print(df["Internship"].value_counts())


# Sort Students by CGPA


print("Students Sorted by CGPA:")
print(df.sort_values("CGPA", ascending=False))


# Highest CGPA


print("Highest CGPA:")
print(df["CGPA"].max())



# Lowest CGPA


print("Lowest CGPA:")
print(df["CGPA"].min())


#Save Dataset as CSV


df.to_csv("job_placement_dataset.csv", index=False)

print("Dataset saved successfully!")


#Load Dataset from CSV


new_df = pd.read_csv("job_placement_dataset.csv")

print("Loaded Dataset:")
print(new_df.head())
# Out:
#     Student_ID  CGPA  Aptitude_Score  Technical_Score  Communication_Score  \
# 0            1   8.5              85               88                   80
# 1            2   7.2              72               75                   72
# 2            3   6.1              55               52                   60
# 3            4   8.9              92               95                   90
# 4            5   7.8              78               82                   75
# 5            6   5.9              48               45                   55
# 6            7   8.2              88               90                   85
# 7            8   6.8              62               65                   65
# 8            9   7.5              75               78                   78
# 9           10   9.0              95               96                   92
# 10          11   6.3              58               55                   58
# ...
